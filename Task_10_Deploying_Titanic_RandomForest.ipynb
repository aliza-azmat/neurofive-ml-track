# %% [markdown]
# # Task 10: Deploying a Machine Learning Model
#
# ## Objective
#
# Deploy the best-performing machine learning model from previous tasks as an interactive Streamlit web application.
#
# The Random Forest Classifier from Task 8 will be used because it achieved the highest accuracy of 82.68% among the models evaluated in that task.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b10202c6-9ad0-4429-9447-58cff26e1cb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b10202c6-9ad0-4429-9447-58cff26e1cb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("train.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (891, 12)
#
# Columns:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# ## Step 2: Load the Titanic Dataset
#
# The Titanic `train.csv` dataset was loaded into a Pandas DataFrame. The same dataset and preprocessing approach used for the Random Forest model in Task 8 will be used to recreate the best-performing model for deployment.

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

df["Embarked"] = df["Embarked"].fillna(
    df["Embarked"].mode()[0]
)

# %%
df = df.drop(
    columns=["PassengerId", "Name", "Ticket", "Cabin"]
)

# %%
from sklearn.preprocessing import LabelEncoder

sex_encoder = LabelEncoder()
embarked_encoder = LabelEncoder()

df["Sex"] = sex_encoder.fit_transform(df["Sex"])
df["Embarked"] = embarked_encoder.fit_transform(df["Embarked"])

# %%
print(df.info())
print("\nMissing values:")
print(df.isnull().sum())

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB
# None
#
# Missing values:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# ...

# %% [markdown]
# ## Step 3: Preprocess the Titanic Dataset
#
# The Titanic dataset was preprocessed using the same approach used for the Random Forest model in Task 8. Missing values in `Age` and `Embarked` were handled using the median and mode respectively. Unnecessary columns were removed, and the categorical `Sex` and `Embarked` features were converted into numerical values using LabelEncoder.

# %%
X = df.drop("Survived", axis=1)
y = df["Survived"]

print("Features:")
print(X.columns.tolist())

print("\nFeature shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features:
# ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
#
# Feature shape: (891, 7)
# Target shape: (891,)

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

random_forest_model.fit(X, y)

print("Random Forest model trained successfully!")
# Out:
# Random Forest model trained successfully!

# %% [markdown]
# ## Step 4: Train the Random Forest Model
#
# The preprocessed Titanic data was separated into input features and the target variable `Survived`. A Random Forest Classifier with 100 decision trees was then trained using the complete training dataset.
#
# Random Forest was selected for deployment because it achieved the highest accuracy (82.68%) among the models compared in Task 8.

# %%
import joblib

# %%
joblib.dump(
    random_forest_model,
    "titanic_random_forest.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
joblib.dump(
    sex_encoder,
    "sex_encoder.pkl"
)

joblib.dump(
    embarked_encoder,
    "embarked_encoder.pkl"
)

print("Encoders saved successfully!")
# Out:
# Encoders saved successfully!

# %%
import os

print("Saved files:")

for file in [
    "titanic_random_forest.pkl",
    "sex_encoder.pkl",
    "embarked_encoder.pkl"
]:
    print(file, "→", os.path.exists(file))
# Out:
# Saved files:
# titanic_random_forest.pkl → True
# sex_encoder.pkl → True
# embarked_encoder.pkl → True

# %% [markdown]
# ## Step 5: Save the Model Using Joblib
#
# The trained Random Forest model was saved using Joblib as `titanic_random_forest.pkl`. The `Sex` and `Embarked` encoders were also saved so that the Streamlit application can apply the same preprocessing to user inputs before making predictions.

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 62.8 MB/s eta 0:00:00
# ...

# %%
import streamlit as st

print("Streamlit installed successfully!")
# Out:
# Streamlit installed successfully!

# %% [markdown]
# ## Step 6: Install Streamlit
#
# Streamlit was installed to build an interactive web application that allows users to enter Titanic passenger information and receive a survival prediction from the trained Random Forest model.

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import joblib

# Load the trained model and encoders
model = joblib.load("titanic_random_forest.pkl")
sex_encoder = joblib.load("sex_encoder.pkl")
embarked_encoder = joblib.load("embarked_encoder.pkl")

# App title
st.title("🚢 Titanic Survival Prediction")

st.write(
    "Enter the passenger details below to predict whether "
    "the passenger would survive."
)

# Input fields
pclass = st.selectbox(
    "Passenger Class",
    [1, 2, 3]
)

sex = st.selectbox(
    "Sex",
    ["female", "male"]
)

age = st.number_input(
    "Age",
    min_value=0.0,
    max_value=100.0,
    value=30.0
)

sibsp = st.number_input(
    "Number of Siblings/Spouses",
    min_value=0,
    max_value=10,
    value=0
)

parch = st.number_input(
    "Number of Parents/Children",
    min_value=0,
    max_value=10,
    value=0
)

fare = st.number_input(
    "Fare",
    min_value=0.0,
    value=30.0
)

embarked = st.selectbox(
    "Port of Embarkation",
    ["C", "Q", "S"]
)

# Prediction button
if st.button("Predict Survival"):

    # Encode categorical inputs
    sex_encoded = sex_encoder.transform([sex])[0]
    embarked_encoded = embarked_encoder.transform([embarked])[0]

    # Create input dataframe
    input_data = pd.DataFrame({
        "Pclass": [pclass],
        "Sex": [sex_encoded],
        "Age": [age],
        "SibSp": [sibsp],
        "Parch": [parch],
        "Fare": [fare],
        "Embarked": [embarked_encoded]
    })

    # Make prediction
    prediction = model.predict(input_data)[0]

    # Display result
    if prediction == 1:
        st.success("✅ Prediction: The passenger is likely to survive.")
    else:
        st.error("❌ Prediction: The passenger is unlikely to survive.")
# Out:
# Writing app.py

# %%
import os

print("app.py created:", os.path.exists("app.py"))
# Out:
# app.py created: True

# %% [markdown]
# ## Step 7: Build the Streamlit Application
#
# A Streamlit application was created to provide an interactive interface for the Titanic survival prediction model. Users can enter passenger information including class, sex, age, family information, fare, and embarkation port.
#
# The application loads the saved Random Forest model and preprocessing encoders using Joblib. When the user clicks the prediction button, the application processes the inputs and displays the predicted survival outcome.

# %%
import os

files = [
    "app.py",
    "titanic_random_forest.pkl",
    "sex_encoder.pkl",
    "embarked_encoder.pkl"
]

for file in files:
    print(file, "→", os.path.exists(file))
# Out:
# app.py → True
# titanic_random_forest.pkl → True
# sex_encoder.pkl → True
# embarked_encoder.pkl → True

# %%
test_input = pd.DataFrame({
    "Pclass": [1],
    "Sex": [sex_encoder.transform(["female"])[0]],
    "Age": [25],
    "SibSp": [0],
    "Parch": [0],
    "Fare": [50],
    "Embarked": [embarked_encoder.transform(["S"])[0]]
})

test_prediction = random_forest_model.predict(test_input)[0]

print("Test prediction:", test_prediction)
# Out:
# Test prediction: 1

# %% [markdown]
# ## Step 8: Test the Model Prediction
#
# The trained Random Forest model was tested using sample passenger information to verify that the model can successfully process the expected input features and generate a survival prediction before deployment.

# %%
# %%writefile requirements.txt
#
# streamlit
# pandas
# scikit-learn
# joblib
# Out:
# Writing requirements.txt

# %%
print(open("requirements.txt").read())
# Out:
# streamlit
# pandas
# scikit-learn
# joblib

# %% [markdown]
# ## Step 9: Create Requirements File
#
# A `requirements.txt` file was created to specify the Python libraries required to run the Streamlit application. This allows the deployment platform to automatically install the necessary dependencies.

# %%
from google.colab import files

files.download("app.py")

# %%
files.download("titanic_random_forest.pkl")

# %%
files.download("sex_encoder.pkl")

# %%
files.download("embarked_encoder.pkl")

# %%
files.download("requirements.txt")
